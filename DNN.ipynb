# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import tensorflow as tf
from sklearn.model_selection import train_test_split
import keras
from tensorflow.keras.optimizers import AdamW

# %%
data = pd.read_csv("Airline_Delay_Cause.csv")

# %%
data
# Out:
#         year  month carrier          carrier_name airport  \
# 0       2022      5      9E     Endeavor Air Inc.     ABE
# 1       2022      5      9E     Endeavor Air Inc.     ABY
# 2       2022      5      9E     Endeavor Air Inc.     ACK
# 3       2022      5      9E     Endeavor Air Inc.     AEX
# 4       2022      5      9E     Endeavor Air Inc.     AGS
# ...      ...    ...     ...                   ...     ...
# 318012  2003      6      DL  Delta Air Lines Inc.     SEA
# 318013  2003      6      DL  Delta Air Lines Inc.     SFO
# 318014  2003      6      DL  Delta Air Lines Inc.     SJC
# 318015  2003      6      DL  Delta Air Lines Inc.     SJU
# 318016  2003      6      DL  Delta Air Lines Inc.     SLC
#
#                                              airport_name  arr_flights  \
# 0       Allentown/Bethlehem/Easton, PA: Lehigh Valley ...        136.0
# 1                  Albany, GA: Southwest Georgia Regional         91.0
# 2                       Nantucket, MA: Nantucket Memorial         19.0
# 3                Alexandria, LA: Alexandria International         88.0
# 4             Augusta, GA: Augusta Regional at Bush Field        181.0
# ...                                                   ...          ...
# 318012          Seattle, WA: Seattle/Tacoma International        480.0
# 318013     San Francisco, CA: San Francisco International        505.0
# 318014  San Jose, CA: Norman Y. Mineta San Jose Intern...        146.0
# 318015       San Juan, PR: Luis Munoz Marin International         95.0
# 318016   Salt Lake City, UT: Salt Lake City International       3466.0
#
#         arr_del15  carrier_ct  weather_ct  ...  security_ct  late_aircraft_ct  \
# 0             7.0        5.95        0.00  ...          0.0              1.00
# 1            16.0        7.38        0.00  ...          0.0              6.09
# 2             2.0        0.13        0.00  ...          0.0              0.88
# 3            14.0        7.26        0.76  ...          0.0              1.64
# 4            19.0       13.84        0.00  ...          0.0              2.09
# ...           ...         ...         ...  ...          ...               ...
# 318012       84.0       25.69        3.09  ...          0.0             21.26
# 318013      111.0       21.78        2.24  ...          0.0             13.17
# 318014       36.0        6.99        0.00  ...          0.0              2.15
# 318015       13.0        3.66        0.00  ...          0.0              1.42
# 318016      454.0      121.15        7.61  ...          1.0            102.33
#
#         arr_cancelled  arr_diverted  arr_delay  carrier_delay  weather_delay  \
# 0                 0.0           0.0      255.0          222.0            0.0
# 1                 0.0           0.0      884.0          351.0            0.0
# 2                 1.0           0.0      138.0            4.0            0.0
# 3                 0.0           0.0      947.0          585.0           35.0
# 4                 0.0           0.0      808.0          662.0            0.0
# ...               ...           ...        ...            ...            ...
# 318012            0.0           0.0     3744.0          978.0          164.0
# 318013            3.0           0.0     4284.0         1376.0          138.0
# 318014            0.0           0.0      896.0          205.0            0.0
# 318015            0.0           0.0      367.0          120.0            0.0
# 318016            9.0           0.0    16853.0         5384.0          306.0
#
#         nas_delay  security_delay  late_aircraft_delay
# 0             4.0             0.0                 29.0
# 1            81.0             0.0                452.0
# 2           106.0             0.0                 28.0
# 3           125.0             0.0                202.0
# 4            87.0             0.0                 59.0
# ...           ...             ...                  ...
# 318012     1023.0             0.0               1579.0
# 318013     2132.0             0.0                638.0
# 318014      607.0             0.0                 84.0
# 318015      210.0             0.0                 37.0
# 318016     5686.0            28.0               5449.0
#
# [318017 rows x 21 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318017 entries, 0 to 318016
# Data columns (total 21 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   year                 318017 non-null  int64
#  1   month                318017 non-null  int64
#  2   carrier              318013 non-null  object
#  3   carrier_name         318013 non-null  object
#  4   airport              318014 non-null  object
#  5   airport_name         318017 non-null  object
#  6   arr_flights          317524 non-null  float64
#  7   arr_del15            317285 non-null  float64
#  8   carrier_ct           317525 non-null  float64
#  9   weather_ct           317523 non-null  float64
#  10  nas_ct               317529 non-null  float64
#  11  security_ct          317529 non-null  float64
#  12  late_aircraft_ct     317529 non-null  float64
#  13  arr_cancelled        317529 non-null  float64
#  14  arr_diverted         317527 non-null  float64
#  15  arr_delay            317523 non-null  float64
#  16  carrier_delay        317525 non-null  float64
#  17  weather_delay        317529 non-null  float64
#  18  nas_delay            317529 non-null  float64
#  19  security_delay       317527 non-null  float64
#  20  late_aircraft_delay  317529 non-null  float64
# dtypes: float64(15), int64(2), object(4)
# memory usage: 51.0+ MB

# %%
data = data.drop(['carrier','carrier_name','airport','airport_name'],axis=1)

# %%
data.dropna(inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 317268 entries, 0 to 318016
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   year                 317268 non-null  int64
#  1   month                317268 non-null  int64
#  2   arr_flights          317268 non-null  float64
#  3   arr_del15            317268 non-null  float64
#  4   carrier_ct           317268 non-null  float64
#  5   weather_ct           317268 non-null  float64
#  6   nas_ct               317268 non-null  float64
#  7   security_ct          317268 non-null  float64
#  8   late_aircraft_ct     317268 non-null  float64
#  9   arr_cancelled        317268 non-null  float64
#  10  arr_diverted         317268 non-null  float64
#  11  arr_delay            317268 non-null  float64
#  12  carrier_delay        317268 non-null  float64
#  13  weather_delay        317268 non-null  float64
#  14  nas_delay            317268 non-null  float64
#  15  security_delay       317268 non-null  float64
#  16  late_aircraft_delay  317268 non-null  float64
# dtypes: float64(15), int64(2)
# memory usage: 43.6 MB

# %%
data['weather_delay'].min(),data['weather_delay'].max()
data['WDCase'] = data['weather_delay'].apply(lambda x : 1 if x >100 else 0)
data['WDCase'].value_counts()
data
# Out:
#         year  month  arr_flights  arr_del15  carrier_ct  weather_ct  nas_ct  \
# 0       2022      5        136.0        7.0        5.95        0.00    0.05
# 1       2022      5         91.0       16.0        7.38        0.00    2.54
# 2       2022      5         19.0        2.0        0.13        0.00    1.00
# 3       2022      5         88.0       14.0        7.26        0.76    4.35
# 4       2022      5        181.0       19.0       13.84        0.00    3.07
# ...      ...    ...          ...        ...         ...         ...     ...
# 318012  2003      6        480.0       84.0       25.69        3.09   33.96
# 318013  2003      6        505.0      111.0       21.78        2.24   73.81
# 318014  2003      6        146.0       36.0        6.99        0.00   26.85
# 318015  2003      6         95.0       13.0        3.66        0.00    7.92
# 318016  2003      6       3466.0      454.0      121.15        7.61  221.91
#
#         security_ct  late_aircraft_ct  arr_cancelled  arr_diverted  arr_delay  \
# 0               0.0              1.00            0.0           0.0      255.0
# 1               0.0              6.09            0.0           0.0      884.0
# 2               0.0              0.88            1.0           0.0      138.0
# 3               0.0              1.64            0.0           0.0      947.0
# 4               0.0              2.09            0.0           0.0      808.0
# ...             ...               ...            ...           ...        ...
# 318012          0.0             21.26            0.0           0.0     3744.0
# 318013          0.0             13.17            3.0           0.0     4284.0
# 318014          0.0              2.15            0.0           0.0      896.0
# 318015          0.0              1.42            0.0           0.0      367.0
# 318016          1.0            102.33            9.0           0.0    16853.0
#
#         carrier_delay  weather_delay  nas_delay  security_delay  \
# 0               222.0            0.0        4.0             0.0
# 1               351.0            0.0       81.0             0.0
# 2                 4.0            0.0      106.0             0.0
# 3               585.0           35.0      125.0             0.0
# 4               662.0            0.0       87.0             0.0
# ...               ...            ...        ...             ...
# 318012          978.0          164.0     1023.0             0.0
# 318013         1376.0          138.0     2132.0             0.0
# 318014          205.0            0.0      607.0             0.0
# 318015          120.0            0.0      210.0             0.0
# 318016         5384.0          306.0     5686.0            28.0
#
#         late_aircraft_delay  WDCase
# 0                      29.0       0
# 1                     452.0       0
# 2                      28.0       0
# 3                     202.0       0
# 4                      59.0       0
# ...                     ...     ...
# 318012               1579.0       1
# 318013                638.0       1
# 318014                 84.0       0
# 318015                 37.0       0
# 318016               5449.0       1
#
# [317268 rows x 18 columns]

# %%
X = data.drop(['WDCase'],axis = 1)
y =data['WDCase']
X
# Out:
#         year  month  arr_flights  arr_del15  carrier_ct  weather_ct  nas_ct  \
# 0       2022      5        136.0        7.0        5.95        0.00    0.05
# 1       2022      5         91.0       16.0        7.38        0.00    2.54
# 2       2022      5         19.0        2.0        0.13        0.00    1.00
# 3       2022      5         88.0       14.0        7.26        0.76    4.35
# 4       2022      5        181.0       19.0       13.84        0.00    3.07
# ...      ...    ...          ...        ...         ...         ...     ...
# 318012  2003      6        480.0       84.0       25.69        3.09   33.96
# 318013  2003      6        505.0      111.0       21.78        2.24   73.81
# 318014  2003      6        146.0       36.0        6.99        0.00   26.85
# 318015  2003      6         95.0       13.0        3.66        0.00    7.92
# 318016  2003      6       3466.0      454.0      121.15        7.61  221.91
#
#         security_ct  late_aircraft_ct  arr_cancelled  arr_diverted  arr_delay  \
# 0               0.0              1.00            0.0           0.0      255.0
# 1               0.0              6.09            0.0           0.0      884.0
# 2               0.0              0.88            1.0           0.0      138.0
# 3               0.0              1.64            0.0           0.0      947.0
# 4               0.0              2.09            0.0           0.0      808.0
# ...             ...               ...            ...           ...        ...
# 318012          0.0             21.26            0.0           0.0     3744.0
# 318013          0.0             13.17            3.0           0.0     4284.0
# 318014          0.0              2.15            0.0           0.0      896.0
# 318015          0.0              1.42            0.0           0.0      367.0
# 318016          1.0            102.33            9.0           0.0    16853.0
#
#         carrier_delay  weather_delay  nas_delay  security_delay  \
# 0               222.0            0.0        4.0             0.0
# 1               351.0            0.0       81.0             0.0
# 2                 4.0            0.0      106.0             0.0
# 3               585.0           35.0      125.0             0.0
# 4               662.0            0.0       87.0             0.0
# ...               ...            ...        ...             ...
# 318012          978.0          164.0     1023.0             0.0
# 318013         1376.0          138.0     2132.0             0.0
# 318014          205.0            0.0      607.0             0.0
# 318015          120.0            0.0      210.0             0.0
# 318016         5384.0          306.0     5686.0            28.0
#
#         late_aircraft_delay
# 0                      29.0
# 1                     452.0
# 2                      28.0
# 3                     202.0
# 4                      59.0
# ...                     ...
# 318012               1579.0
# 318013                638.0
# 318014                 84.0
# 318015                 37.0
# 318016               5449.0
#
# [317268 rows x 17 columns]

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 318012    1
# 318013    1
# 318014    0
# 318015    0
# 318016    1
# Name: WDCase, Length: 317268, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=44, shuffle =True)

print('X_train shape is ' , X_train.shape)
print('X_test shape is ' , X_test.shape)
print('y_train shape is ' , y_train.shape)
print('y_test shape is ' , y_test.shape)
# Out:
# X_train shape is  (237951, 17)
# X_test shape is  (79317, 17)
# y_train shape is  (237951,)
# y_test shape is  (79317,)

# %%
KerasModel = keras.models.Sequential([
            # keras.layers.Input(shape=(17)),
            keras.layers.Dense(8,  activation = 'tanh'),
            # keras.layers.Dropout(0.1),
            keras.layers.Dense(128, activation = 'sigmoid'),
            # keras.layers.Dropout(0.3),
            keras.layers.Dense(64, activation = 'tanh'),
            keras.layers.Dense(32, activation = 'tanh'),
            keras.layers.Dropout(0.2),
            keras.layers.Dense(1, activation = 'sigmoid')
            ])

# %%
MyOptimizer = AdamW(
    learning_rate=0.001,
    weight_decay=0.004,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    amsgrad=False,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    name="AdamW"
)

# %%
KerasModel.compile(optimizer =MyOptimizer,loss='binary_crossentropy',metrics=['accuracy']) # matrix

# %%
history = KerasModel.fit(X_train,y_train,
                         validation_data=(X_test,y_test),
                         epochs=100,
                         batch_size=10000,
                         verbose=1,
                         callbacks=[tf.keras.callbacks.EarlyStopping(
                                            patience=10,
                                            monitor='val_accuracy',#"val_loss",
                                            restore_best_weights=True)])
# Out:
# Epoch 1/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - accuracy: 0.6415 - loss: 0.6448 - val_accuracy: 0.6773 - val_loss: 0.5613
# Epoch 2/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6998 - loss: 0.5540 - val_accuracy: 0.7285 - val_loss: 0.5260
# Epoch 3/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7321 - loss: 0.5243 - val_accuracy: 0.7451 - val_loss: 0.5134
# Epoch 4/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7434 - loss: 0.5132 - val_accuracy: 0.7542 - val_loss: 0.5058
# Epoch 5/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7538 - loss: 0.5048 - val_accuracy: 0.7537 - val_loss: 0.4994
# Epoch 6/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7565 - loss: 0.4987 - val_accuracy: 0.7558 - val_loss: 0.4946
# Epoch 7/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7545 - loss: 0.4955 - val_accuracy: 0.7557 - val_loss: 0.4893
# Epoch 8/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7571 - loss: 0.4889 - val_accuracy: 0.7570 - val_loss: 0.4865
# Epoch 9/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7549 - loss: 0.4868 - val_accuracy: 0.7484 - val_loss: 0.4825
# Epoch 10/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7545 - loss: 0.4816 - val_accuracy: 0.7607 - val_loss: 0.4783
# Epoch 11/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7590 - loss: 0.4787 - val_accuracy: 0.7597 - val_loss: 0.4747
# Epoch 12/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7590 - loss: 0.4748 - val_accuracy: 0.7587 - val_loss: 0.4718
# Epoch 13/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7604 - loss: 0.4708 - val_accuracy: 0.7662 - val_loss: 0.4678
# Epoch 14/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7644 - loss: 0.4684 - val_accuracy: 0.7609 - val_loss: 0.4654
# Epoch 15/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7681 - loss: 0.4654 - val_accuracy: 0.7749 - val_loss: 0.4624
# Epoch 16/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7756 - loss: 0.4619 - val_accuracy: 0.7768 - val_loss: 0.4602
# Epoch 17/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7767 - loss: 0.4587 - val_accuracy: 0.7812 - val_loss: 0.4555
# Epoch 18/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7838 - loss: 0.4518 - val_accuracy: 0.7811 - val_loss: 0.4495
# Epoch 19/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7793 - loss: 0.4489 - val_accuracy: 0.7783 - val_loss: 0.4448
# Epoch 20/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7797 - loss: 0.4446 - val_accuracy: 0.7814 - val_loss: 0.4399
# Epoch 21/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7824 - loss: 0.4375 - val_accuracy: 0.7950 - val_loss: 0.4348
# Epoch 22/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8003 - loss: 0.4323 - val_accuracy: 0.8007 - val_loss: 0.4267
# Epoch 23/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7991 - loss: 0.4248 - val_accuracy: 0.7886 - val_loss: 0.4162
# Epoch 24/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7980 - loss: 0.4117 - val_accuracy: 0.8119 - val_loss: 0.4008
# Epoch 25/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8134 - loss: 0.3934 - val_accuracy: 0.7941 - val_loss: 0.3791
# Epoch 26/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8065 - loss: 0.3693 - val_accuracy: 0.8569 - val_loss: 0.3343
# Epoch 27/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8711 - loss: 0.3172 - val_accuracy: 0.9086 - val_loss: 0.2663
# Epoch 28/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9209 - loss: 0.2398 - val_accuracy: 0.9517 - val_loss: 0.1614
# Epoch 29/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9523 - loss: 0.1553 - val_accuracy: 0.9628 - val_loss: 0.1234
# Epoch 30/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9680 - loss: 0.1112 - val_accuracy: 0.9836 - val_loss: 0.0715
# Epoch 31/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9858 - loss: 0.0635 - val_accuracy: 0.9920 - val_loss: 0.0375
# Epoch 32/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9898 - loss: 0.0482 - val_accuracy: 0.9944 - val_loss: 0.0289
# Epoch 33/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9936 - loss: 0.0319 - val_accuracy: 0.9922 - val_loss: 0.0349
# Epoch 34/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9907 - loss: 0.0465 - val_accuracy: 0.9915 - val_loss: 0.0408
# Epoch 35/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9919 - loss: 0.0402 - val_accuracy: 0.9948 - val_loss: 0.0246
# Epoch 36/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9933 - loss: 0.0341 - val_accuracy: 0.9936 - val_loss: 0.0328
# Epoch 37/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9949 - loss: 0.0257 - val_accuracy: 0.9966 - val_loss: 0.0162
# Epoch 38/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9969 - loss: 0.0163 - val_accuracy: 0.9946 - val_loss: 0.0280
# Epoch 39/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9959 - loss: 0.0212 - val_accuracy: 0.9962 - val_loss: 0.0177
# Epoch 40/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9968 - loss: 0.0162 - val_accuracy: 0.9965 - val_loss: 0.0181
# Epoch 41/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9966 - loss: 0.0173 - val_accuracy: 0.9973 - val_loss: 0.0143
# Epoch 42/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9975 - loss: 0.0130 - val_accuracy: 0.9966 - val_loss: 0.0145
# Epoch 43/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9963 - loss: 0.0188 - val_accuracy: 0.9958 - val_loss: 0.0206
# Epoch 44/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9962 - loss: 0.0192 - val_accuracy: 0.9971 - val_loss: 0.0139
# Epoch 45/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9967 - loss: 0.0166 - val_accuracy: 0.9982 - val_loss: 0.0090
# Epoch 46/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9975 - loss: 0.0118 - val_accuracy: 0.9981 - val_loss: 0.0090
# Epoch 47/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9979 - loss: 0.0102 - val_accuracy: 0.9870 - val_loss: 0.0511
# Epoch 48/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9896 - loss: 0.0415 - val_accuracy: 0.9960 - val_loss: 0.0159
# Epoch 49/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9972 - loss: 0.0137 - val_accuracy: 0.9977 - val_loss: 0.0103
# Epoch 50/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9980 - loss: 0.0095 - val_accuracy: 0.9976 - val_loss: 0.0123
# Epoch 51/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9981 - loss: 0.0097 - val_accuracy: 0.9984 - val_loss: 0.0073
# Epoch 52/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9981 - loss: 0.0085 - val_accuracy: 0.9984 - val_loss: 0.0077
# Epoch 53/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9981 - loss: 0.0088 - val_accuracy: 0.9985 - val_loss: 0.0075
# Epoch 54/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9976 - loss: 0.0113 - val_accuracy: 0.9973 - val_loss: 0.0137
# Epoch 55/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9976 - loss: 0.0121 - val_accuracy: 0.9981 - val_loss: 0.0080
# Epoch 56/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9969 - loss: 0.0154 - val_accuracy: 0.9979 - val_loss: 0.0107
# Epoch 57/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9983 - loss: 0.0091 - val_accuracy: 0.9987 - val_loss: 0.0064
# Epoch 58/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9984 - loss: 0.0078 - val_accuracy: 0.9980 - val_loss: 0.0091
# Epoch 59/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9976 - loss: 0.0120 - val_accuracy: 0.9987 - val_loss: 0.0063
# Epoch 60/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9984 - loss: 0.0071 - val_accuracy: 0.9984 - val_loss: 0.0068
# Epoch 61/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9982 - loss: 0.0082 - val_accuracy: 0.9982 - val_loss: 0.0080
# Epoch 62/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9981 - loss: 0.0087 - val_accuracy: 0.9988 - val_loss: 0.0050
# Epoch 63/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9984 - loss: 0.0076 - val_accuracy: 0.9981 - val_loss: 0.0076
# Epoch 64/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9979 - loss: 0.0093 - val_accuracy: 0.9952 - val_loss: 0.0222
# Epoch 65/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9966 - loss: 0.0163 - val_accuracy: 0.9972 - val_loss: 0.0124
# Epoch 66/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9977 - loss: 0.0111 - val_accuracy: 0.9986 - val_loss: 0.0056
# Epoch 67/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9982 - loss: 0.0079 - val_accuracy: 0.9970 - val_loss: 0.0142
# Epoch 68/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9976 - loss: 0.0114 - val_accuracy: 0.9983 - val_loss: 0.0080
# Epoch 69/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9981 - loss: 0.0087 - val_accuracy: 0.9988 - val_loss: 0.0049
# Epoch 70/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9987 - loss: 0.0057 - val_accuracy: 0.9979 - val_loss: 0.0089
# Epoch 71/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9983 - loss: 0.0075 - val_accuracy: 0.9975 - val_loss: 0.0132
# Epoch 72/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9981 - loss: 0.0092 - val_accuracy: 0.9980 - val_loss: 0.0083
# Epoch 73/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9984 - loss: 0.0072 - val_accuracy: 0.9983 - val_loss: 0.0062
# Epoch 74/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9985 - loss: 0.0061 - val_accuracy: 0.9988 - val_loss: 0.0045
# Epoch 75/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9987 - loss: 0.0054 - val_accuracy: 0.9954 - val_loss: 0.0220
# Epoch 76/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9975 - loss: 0.0118 - val_accuracy: 0.9959 - val_loss: 0.0226
# Epoch 77/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9981 - loss: 0.0100 - val_accuracy: 0.9981 - val_loss: 0.0074
# Epoch 78/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9986 - loss: 0.0059 - val_accuracy: 0.9989 - val_loss: 0.0047
# Epoch 79/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9988 - loss: 0.0048 - val_accuracy: 0.9987 - val_loss: 0.0052
# Epoch 80/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9988 - loss: 0.0049 - val_accuracy: 0.9988 - val_loss: 0.0047
# Epoch 81/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9988 - loss: 0.0053 - val_accuracy: 0.9974 - val_loss: 0.0120
# Epoch 82/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9983 - loss: 0.0077 - val_accuracy: 0.9957 - val_loss: 0.0225
# Epoch 83/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9973 - loss: 0.0124 - val_accuracy: 0.9992 - val_loss: 0.0040
# Epoch 84/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9986 - loss: 0.0063 - val_accuracy: 0.9987 - val_loss: 0.0052
# Epoch 85/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9981 - loss: 0.0088 - val_accuracy: 0.9991 - val_loss: 0.0043
# Epoch 86/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9988 - loss: 0.0055 - val_accuracy: 0.9980 - val_loss: 0.0087
# Epoch 87/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9984 - loss: 0.0070 - val_accuracy: 0.9978 - val_loss: 0.0087
# Epoch 88/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9979 - loss: 0.0102 - val_accuracy: 0.9989 - val_loss: 0.0045
# Epoch 89/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9989 - loss: 0.0046 - val_accuracy: 0.9981 - val_loss: 0.0075
# Epoch 90/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9984 - loss: 0.0067 - val_accuracy: 0.9980 - val_loss: 0.0073
# Epoch 91/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9988 - loss: 0.0049 - val_accuracy: 0.9984 - val_loss: 0.0059
# Epoch 92/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9987 - loss: 0.0053 - val_accuracy: 0.9978 - val_loss: 0.0097
# Epoch 93/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9985 - loss: 0.0057 - val_accuracy: 0.9984 - val_loss: 0.0066

# %%
print(KerasModel.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 8)                   │             144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │           1,152 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 34,997 (136.71 KB)
#  Trainable params: 11,665 (45.57 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 23,332 (91.14 KB)
# None

# %%
KerasModel.save('KerasModel.keras')

# %%
NewKerasModel = keras.models.load_model('KerasModel.keras')

# %%
y_pred = NewKerasModel.predict(X_test)
# Out:
# 2479/2479 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step

# %%
print('Prediction Shape is {}'.format(y_pred.shape))
print('Prediction items are {}'.format(y_pred[:5]))
# Out:
# Prediction Shape is (79317, 1)
# Prediction items are [[9.9857938e-01]
#  [9.9857938e-01]
#  [2.4648278e-04]
#  [1.0218588e-04]
#  [2.4648278e-04]]

# %%
y_test[:5]
# Out:
# 256596    1
# 6930      1
# 125951    0
# 87817     0
# 42037     0
# Name: WDCase, dtype: int64

# %%
ModelLoss, ModelAccuracy = NewKerasModel.evaluate(X_test, y_test)
print('Model Loss is {}'.format(ModelLoss))
print('Model Accuracy is {}'.format(ModelAccuracy ))
# Out:
# 2479/2479 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9992 - loss: 0.0039
# Model Loss is 0.003953882493078709
# Model Accuracy is 0.9991804957389832

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
